# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import CosineDecay
import time
import gc

print("--- STARTING KAGGLE BATCH EXECUTION: BOOSTED RESNET-50 ---")

# ==========================================
# PART 1: DATA PIPELINE (MEMORY-SAFE)
# ==========================================
DATASET_PATH = "/kaggle/input/datasets/yashaswi15/aerosense-training-data/Delhi_NCR_Master_DataCube_Scaled.npy"

master_data = np.load(DATASET_PATH, mmap_mode='r')
total_days = master_data.shape[0]
train_split = int(total_days * 0.8) 
test_split = total_days - train_split 

class SpatiotemporalGenerator(Sequence):
    def __init__(self, data_cube, start_idx, end_idx, batch_size=16):
        self.data_cube = data_cube
        self.start_idx = start_idx
        self.end_idx = end_idx - 8 
        self.batch_size = batch_size
        self.indices = np.arange(self.start_idx, self.end_idx)
        
    def __len__(self):
        return int(np.ceil(len(self.indices) / self.batch_size))
    
    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        X_batch, Y_batch = [], []
        for i in batch_indices:
            window = self.data_cube[i : i+7]
            X_flat = np.transpose(window, (1, 2, 0, 3)).reshape((141, 231, 42))
            X_batch.append(X_flat)
            Y_batch.append(self.data_cube[i+7])
            
        X_batch = np.nan_to_num(np.array(X_batch), nan=0.0)
        Y_batch = np.nan_to_num(np.array(Y_batch), nan=0.0)
        return X_batch, Y_batch

train_gen = SpatiotemporalGenerator(master_data, 0, train_split, batch_size=16)
test_gen = SpatiotemporalGenerator(master_data, train_split, total_days, batch_size=16)

# ==========================================
# PART 2: BOOSTED RESNET-50 ARCHITECTURE (FIXED)
# ==========================================
def build_resnet50_boosted(input_shape=(141, 231, 42)):
    inputs = layers.Input(shape=input_shape)
    
    # 1. ImageNet Adapter (42 channels -> 3 channels)
    adapter = layers.Conv2D(3, (1, 1), padding='same', activation='relu')(inputs)
    
    # 2. ResNet Base - FIX: Build it completely independently with exactly 3 channels!
    # Notice we use input_shape instead of input_tensor here.
    base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(141, 231, 3))
    base_model.trainable = True 
    
    # NOW we pass our adapter data through the fully-loaded ResNet
    x = base_model(adapter)
    
    # 3. Upsampling Decoder
    x = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(64,  (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(32,  (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(16,  (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    
    x = layers.Resizing(141, 231)(x)
    
    # 4. THE MAGIC SHORTCUT: Concatenate original input to prevent blurriness
    x = layers.Concatenate()([x, inputs])
    
    # 5. Smoothing & Output
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    outputs = layers.Conv2D(6, (1, 1), activation='sigmoid')(x)
    
    return Model(inputs=inputs, outputs=outputs, name="Boosted_ResNet50")

resnet_model = build_resnet50_boosted()
# ==========================================
# PART 3: ADVANCED CUSTOM TRAINING LOOP
# ==========================================
MODEL_SAVE_PATH = "/kaggle/working/Delhi_NCR_ResNet50_Best.keras"

initial_learning_rate = 0.001
decay_steps = 50 * len(train_gen)
lr_schedule = CosineDecay(initial_learning_rate, decay_steps)
optimizer = Adam(learning_rate=lr_schedule, clipnorm=1.0)

# MATCHING U-NET EXACTLY: Using MAE
def calculate_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.abs(y_true - y_pred))

@tf.function
def train_step(x_batch, y_batch):
    with tf.GradientTape() as tape:
        predictions = resnet_model(x_batch, training=True)
        loss = calculate_loss(y_batch, predictions)
    gradients = tape.gradient(loss, resnet_model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, resnet_model.trainable_variables))
    return loss

@tf.function
def val_step(x_batch, y_batch):
    predictions = resnet_model(x_batch, training=False)
    val_loss = calculate_loss(y_batch, predictions)
    return val_loss

EPOCHS = 50
best_val_loss = float('inf')
patience = 7
patience_counter = 0

print(f"\n--- Starting 50-Epoch Backpropagation ---")

for epoch in range(EPOCHS):
    start_time = time.time()
    epoch_loss_avg = tf.keras.metrics.Mean()
    epoch_val_loss_avg = tf.keras.metrics.Mean()
    
    for step in range(len(train_gen)):
        x_batch, y_batch = train_gen[step]
        loss_val = train_step(x_batch, y_batch)
        epoch_loss_avg.update_state(loss_val)
        
    for step in range(len(test_gen)):
        x_val, y_val = test_gen[step]
        v_loss = val_step(x_val, y_val)
        epoch_val_loss_avg.update_state(v_loss)
        
    train_loss = epoch_loss_avg.result().numpy()
    val_loss = epoch_val_loss_avg.result().numpy()
    current_lr = optimizer.learning_rate(optimizer.iterations).numpy() if callable(optimizer.learning_rate) else optimizer.learning_rate.numpy()
        
    print(f"Epoch {epoch+1:02d}/{EPOCHS} | Time: {time.time() - start_time:.1f}s | LR: {current_lr:.5f} | Train Loss: {train_loss:.5f} | Val Loss: {val_loss:.5f}")
    
    if val_loss < best_val_loss:
        print(f"  -> Val Loss improved from {best_val_loss:.5f} to {val_loss:.5f}. Saving weights!")
        best_val_loss = val_loss
        resnet_model.save(MODEL_SAVE_PATH)
        patience_counter = 0
    else:
        patience_counter += 1
        print(f"  -> No improvement. Patience: {patience_counter}/{patience}")
        if patience_counter >= patience:
            print(f"\n[!] Early Stopping Triggered.")
            break
            
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# 2026-04-23 13:05:42.226877: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776949542.573367      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776949542.670765      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776949543.549037      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776949543.549080      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776949543.549082      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776949543.549085      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# --- STARTING KAGGLE BATCH EXECUTION: BOOSTED RESNET-50 ---
# I0000 00:00:1776949581.121501      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#
# --- Starting 50-Epoch Backpropagation ---
# I0000 00:00:1776949622.833689      68 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Epoch 01/50 | Time: 176.9s | LR: 0.00100 | Train Loss: 0.06861 | Val Loss: 0.05391
#   -> Val Loss improved from inf to 0.05391. Saving weights!
# Epoch 02/50 | Time: 126.3s | LR: 0.00100 | Train Loss: 0.04792 | Val Loss: 0.04467
#   -> Val Loss improved from 0.05391 to 0.04467. Saving weights!
# Epoch 03/50 | Time: 126.7s | LR: 0.00099 | Train Loss: 0.04423 | Val Loss: 0.04525
#   -> No improvement. Patience: 1/7
# Epoch 04/50 | Time: 127.2s | LR: 0.00098 | Train Loss: 0.04213 | Val Loss: 0.04195
#   -> Val Loss improved from 0.04467 to 0.04195. Saving weights!
# Epoch 05/50 | Time: 125.6s | LR: 0.00098 | Train Loss: 0.04046 | Val Loss: 0.04023
#   -> Val Loss improved from 0.04195 to 0.04023. Saving weights!
# Epoch 06/50 | Time: 124.9s | LR: 0.00096 | Train Loss: 0.03926 | Val Loss: 0.03935
#   -> Val Loss improved from 0.04023 to 0.03935. Saving weights!
# Epoch 07/50 | Time: 126.7s | LR: 0.00095 | Train Loss: 0.03837 | Val Loss: 0.03841
#   -> Val Loss improved from 0.03935 to 0.03841. Saving weights!
# Epoch 08/50 | Time: 125.7s | LR: 0.00094 | Train Loss: 0.03770 | Val Loss: 0.03804
#   -> Val Loss improved from 0.03841 to 0.03804. Saving weights!
# Epoch 09/50 | Time: 126.4s | LR: 0.00092 | Train Loss: 0.03714 | Val Loss: 0.03731
#   -> Val Loss improved from 0.03804 to 0.03731. Saving weights!
# Epoch 10/50 | Time: 126.4s | LR: 0.00090 | Train Loss: 0.03664 | Val Loss: 0.03637
#   -> Val Loss improved from 0.03731 to 0.03637. Saving weights!
# Epoch 11/50 | Time: 126.5s | LR: 0.00089 | Train Loss: 0.03622 | Val Loss: 0.03599
#   -> Val Loss improved from 0.03637 to 0.03599. Saving weights!
# Epoch 12/50 | Time: 126.5s | LR: 0.00086 | Train Loss: 0.03583 | Val Loss: 0.03552
#   -> Val Loss improved from 0.03599 to 0.03552. Saving weights!
# Epoch 13/50 | Time: 125.8s | LR: 0.00084 | Train Loss: 0.03549 | Val Loss: 0.03536
#   -> Val Loss improved from 0.03552 to 0.03536. Saving weights!
# Epoch 14/50 | Time: 125.7s | LR: 0.00082 | Train Loss: 0.03518 | Val Loss: 0.03508
#   -> Val Loss improved from 0.03536 to 0.03508. Saving weights!
# Epoch 15/50 | Time: 126.1s | LR: 0.00079 | Train Loss: 0.03489 | Val Loss: 0.03469
#   -> Val Loss improved from 0.03508 to 0.03469. Saving weights!
# Epoch 16/50 | Time: 126.6s | LR: 0.00077 | Train Loss: 0.03462 | Val Loss: 0.03452
#   -> Val Loss improved from 0.03469 to 0.03452. Saving weights!
# Epoch 17/50 | Time: 126.5s | LR: 0.00074 | Train Loss: 0.03434 | Val Loss: 0.03508
#   -> No improvement. Patience: 1/7
# Epoch 18/50 | Time: 126.4s | LR: 0.00071 | Train Loss: 0.03403 | Val Loss: 0.03395
#   -> Val Loss improved from 0.03452 to 0.03395. Saving weights!
# Epoch 19/50 | Time: 125.4s | LR: 0.00068 | Train Loss: 0.03378 | Val Loss: 0.03381
#   -> Val Loss improved from 0.03395 to 0.03381. Saving weights!
# Epoch 20/50 | Time: 125.6s | LR: 0.00065 | Train Loss: 0.03356 | Val Loss: 0.03358
#   -> Val Loss improved from 0.03381 to 0.03358. Saving weights!
# Epoch 21/50 | Time: 126.2s | LR: 0.00062 | Train Loss: 0.03336 | Val Loss: 0.03390
#   -> No improvement. Patience: 1/7
# Epoch 22/50 | Time: 126.7s | LR: 0.00059 | Train Loss: 0.03316 | Val Loss: 0.03448
#   -> No improvement. Patience: 2/7
# Epoch 23/50 | Time: 126.5s | LR: 0.00056 | Train Loss: 0.03301 | Val Loss: 0.03408
#   -> No improvement. Patience: 3/7
# Epoch 24/50 | Time: 127.0s | LR: 0.00053 | Train Loss: 0.03282 | Val Loss: 0.03404
#   -> No improvement. Patience: 4/7
# Epoch 25/50 | Time: 128.4s | LR: 0.00050 | Train Loss: 0.03262 | Val Loss: 0.03454
#   -> No improvement. Patience: 5/7
# Epoch 26/50 | Time: 127.2s | LR: 0.00047 | Train Loss: 0.03246 | Val Loss: 0.03360
#   -> No improvement. Patience: 6/7
# Epoch 27/50 | Time: 127.8s | LR: 0.00044 | Train Loss: 0.03231 | Val Loss: 0.03297
#   -> Val Loss improved from 0.03358 to 0.03297. Saving weights!
# Epoch 28/50 | Time: 126.6s | LR: 0.00041 | Train Loss: 0.03216 | Val Loss: 0.03300
#   -> No improvement. Patience: 1/7
# Epoch 29/50 | Time: 127.2s | LR: 0.00038 | Train Loss: 0.03195 | Val Loss: 0.03305
#   -> No improvement. Patience: 2/7
# Epoch 30/50 | Time: 126.7s | LR: 0.00035 | Train Loss: 0.03180 | Val Loss: 0.03313
#   -> No improvement. Patience: 3/7
# Epoch 31/50 | Time: 127.9s | LR: 0.00032 | Train Loss: 0.03151 | Val Loss: 0.03346
#   -> No improvement. Patience: 4/7
# Epoch 32/50 | Time: 127.5s | LR: 0.00029 | Train Loss: 0.03126 | Val Loss: 0.03465
#   -> No improvement. Patience: 5/7
# Epoch 33/50 | Time: 127.7s | LR: 0.00026 | Train Loss: 0.03095 | Val Loss: 0.03532
#   -> No improvement. Patience: 6/7
# Epoch 34/50 | Time: 127.9s | LR: 0.00023 | Train Loss: 0.03051 | Val Loss: 0.03556
#   -> No improvement. Patience: 7/7
#
# [!] Early Stopping Triggered.
